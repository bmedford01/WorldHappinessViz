# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('happiness.json')
df.head()
# Out:
#    Countryname  Dystopia+residual  Explainedby:Freedomtomakelifechoices  \
# 0      Finland              3.253                                 0.691
# 1      Denmark              2.868                                 0.686
# 2  Switzerland              2.839                                 0.653
# 3      Iceland              2.967                                 0.698
# 4  Netherlands              2.798                                 0.647
#
#    Explainedby:Generosity  Explainedby:Healthylifeexpectancy  \
# 0                   0.124                              0.741
# 1                   0.208                              0.763
# 2                   0.204                              0.816
# 3                   0.293                              0.772
# 4                   0.302                              0.753
#
#    Explainedby:LogGDPpercapita  Explainedby:Perceptionsofcorruption  \
# 0                        1.446                                0.481
# ...

# %%
df.keys()
# Out:
# Index(['Countryname', 'Dystopia+residual',
#        'Explainedby:Freedomtomakelifechoices', 'Explainedby:Generosity',
#        'Explainedby:Healthylifeexpectancy', 'Explainedby:LogGDPpercapita',
#        'Explainedby:Perceptionsofcorruption', 'Explainedby:Socialsupport',
#        'Freedomtomakelifechoices', 'Generosity', 'Healthylifeexpectancy',
#        'Ladderscore', 'LadderscoreinDystopia', 'LoggedGDPpercapita',
#        'Perceptionsofcorruption', 'Regionalindicator', 'Socialsupport',
#        'Standarderrorofladderscore', 'lowerwhisker', 'upperwhisker'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Dystopia+residual  Explainedby:Freedomtomakelifechoices  \
# count         149.000000                            149.000000
# mean            2.430329                              0.498711
# std             0.537645                              0.137888
# min             0.648000                              0.000000
# 25%             2.138000                              0.409000
# 50%             2.509000                              0.514000
# 75%             2.794000                              0.603000
# max             3.482000                              0.716000
#
#        Explainedby:Generosity  Explainedby:Healthylifeexpectancy  \
# count              149.000000                         149.000000
# mean                 0.178047                           0.520161
# std                  0.098270                           0.213019
# min                  0.000000                           0.000000
# 25%                  0.105000                           0.357000
# ...

# %%
df.Healthylifeexpectancy
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthylifeexpectancy, Length: 149, dtype: float64

# %%
plt.figure(figsize=[15,6])
plt.scatter(df.Countryname,df.Healthylifeexpectancy)
